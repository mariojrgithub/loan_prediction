# %%
# imports
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('train_u6lujuX_CVtuZ9i.csv', index_col='Loan_ID')
train.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0         NaN             360.0
# LP001003             4583             1508.0       128.0             360.0
# LP001005             3000                0.0        66.0             360.0
# LP001006             2583             2358.0       120.0             360.0
# LP001008             6000                0.0       141.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002             1.0         Urban           Y
# LP001003             1.0         Rural           N
# LP001005             1.0         Urban           Y
# LP001006             1.0         Urban           Y
# LP001008             1.0         Urban           Y

# %%
train.shape
# Out:
# (614, 12)

# %%
test = pd.read_csv('test_Y3wMUE5_7gLdaTN.csv', index_col='Loan_ID')
test.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001015   Male     Yes          0      Graduate            No
# LP001022   Male     Yes          1      Graduate            No
# LP001031   Male     Yes          2      Graduate            No
# LP001035   Male     Yes          2      Graduate            No
# LP001051   Male      No          0  Not Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001015             5720                  0       110.0             360.0
# LP001022             3076               1500       126.0             360.0
# LP001031             5000               1800       208.0             360.0
# LP001035             2340               2546       100.0             360.0
# LP001051             3276                  0        78.0             360.0
#
#           Credit_History Property_Area
# Loan_ID
# LP001015             1.0         Urban
# LP001022             1.0         Urban
# LP001031             1.0         Urban
# LP001035             NaN         Urban
# LP001051             1.0         Urban

# %%
test.shape
# Out:
# (367, 11)

# %%
train.dtypes
# Out:
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
train.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
train['Credit_History'].value_counts()
# Out:
# 1.0    475
# 0.0     89
# Name: Credit_History, dtype: int64

# %%
train[train['Credit_History'].isnull()]
# Out:
#           Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001034    Male      No          1  Not Graduate            No
# LP001052    Male     Yes          1      Graduate           NaN
# LP001091    Male     Yes          1      Graduate           NaN
# LP001123    Male     Yes          0      Graduate            No
# LP001264    Male     Yes         3+  Not Graduate           Yes
# LP001273    Male     Yes          0      Graduate            No
# LP001280    Male     Yes          2  Not Graduate            No
# LP001326    Male      No          0      Graduate           NaN
# LP001405    Male     Yes          1      Graduate            No
# LP001443  Female      No          0      Graduate            No
# LP001465    Male     Yes          0      Graduate            No
# LP001469    Male      No          0      Graduate           Yes
# LP001541    Male     Yes          1      Graduate            No
# LP001634    Male      No          0      Graduate            No
# LP001643    Male     Yes          0      Graduate            No
# LP001671  Female     Yes          0      Graduate            No
# LP001734  Female     Yes          2      Graduate            No
# LP001786    Male     Yes          0      Graduate           NaN
# LP001788  Female      No          0      Graduate           Yes
# LP001864    Male     Yes         3+  Not Graduate            No
# LP001865    Male     Yes          1      Graduate            No
# LP001908  Female     Yes          0  Not Graduate            No
# LP001998    Male     Yes          2  Not Graduate            No
# LP002008    Male     Yes          2      Graduate           Yes
# LP002036    Male     Yes          0      Graduate            No
# LP002043  Female      No          1      Graduate            No
# LP002055  Female      No          0      Graduate            No
# LP002137    Male     Yes          0      Graduate            No
# LP002178    Male     Yes          0      Graduate            No
# LP002223    Male     Yes          0      Graduate            No
# LP002263    Male     Yes          0      Graduate            No
# LP002272    Male     Yes          2      Graduate            No
# LP002319    Male     Yes          0      Graduate           NaN
# LP002424    Male     Yes          0      Graduate            No
# LP002444    Male      No          1  Not Graduate           Yes
# LP002447    Male     Yes          2  Not Graduate            No
# LP002478     NaN     Yes          0      Graduate           Yes
# LP002522  Female      No          0      Graduate           Yes
# LP002560    Male      No          0  Not Graduate            No
# LP002562    Male     Yes          1  Not Graduate            No
# LP002588    Male     Yes          0      Graduate            No
# LP002618    Male     Yes          1  Not Graduate            No
# LP002624    Male     Yes          0      Graduate            No
# LP002717    Male     Yes          0      Graduate            No
# LP002729    Male      No          1      Graduate            No
# LP002757  Female     Yes          0  Not Graduate            No
# LP002794  Female      No          0      Graduate            No
# LP002833    Male     Yes          0  Not Graduate            No
# LP002898    Male     Yes          1      Graduate            No
# LP002949  Female      No         3+      Graduate           NaN
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001034             3596                0.0       100.0             240.0
# LP001052             3717             2925.0       151.0             360.0
# LP001091             4166             3369.0       201.0             360.0
# LP001123             2400                0.0        75.0             360.0
# LP001264             3333             2166.0       130.0             360.0
# LP001273             6000             2250.0       265.0             360.0
# LP001280             3333             2000.0        99.0             360.0
# LP001326             6782                0.0         NaN             360.0
# LP001405             2214             1398.0        85.0             360.0
# LP001443             3692                0.0        93.0             360.0
# LP001465             6080             2569.0       182.0             360.0
# LP001469            20166                0.0       650.0             480.0
# LP001541             6000                0.0       160.0             360.0
# LP001634             1916             5063.0        67.0             360.0
# LP001643             2383             2138.0        58.0             360.0
# LP001671             3416             2816.0       113.0             360.0
# LP001734             4283             2383.0       127.0             360.0
# LP001786             5746                0.0       255.0             360.0
# LP001788             3463                0.0       122.0             360.0
# LP001864             4931                0.0       128.0             360.0
# LP001865             6083             4250.0       330.0             360.0
# LP001908             4100                0.0       124.0             360.0
# LP001998             7667                0.0       185.0             360.0
# LP002008             5746                0.0       144.0              84.0
# LP002036             2058             2134.0        88.0             360.0
# LP002043             3541                0.0       112.0             360.0
# LP002055             3166             2985.0       132.0             360.0
# LP002137             6333             4583.0       259.0             360.0
# LP002178             3013             3033.0        95.0             300.0
# LP002223             4310                0.0       130.0             360.0
# LP002263             2583             2115.0       120.0             360.0
# LP002272             3276              484.0       135.0             360.0
# LP002319             6256                0.0       160.0             360.0
# LP002424             7333             8333.0       175.0             300.0
# LP002444             2769             1542.0       190.0             360.0
# LP002447             1958             1456.0        60.0             300.0
# LP002478             2083             4083.0       160.0             360.0
# LP002522             2500                0.0        93.0             360.0
# LP002560             2699             2785.0        96.0             360.0
# LP002562             5333             1131.0       186.0             360.0
# LP002588             4625             2857.0       111.0              12.0
# LP002618             4050             5302.0       138.0             360.0
# LP002624            20833             6667.0       480.0             360.0
# LP002717             1025             5500.0       216.0             360.0
# LP002729            11250                0.0       196.0             360.0
# LP002757             3017              663.0       102.0             360.0
# LP002794             2667             1625.0        84.0             360.0
# LP002833             4467                0.0       120.0             360.0
# LP002898             1880                0.0        61.0             360.0
# LP002949              416            41667.0       350.0             180.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001034             NaN         Urban           Y
# LP001052             NaN     Semiurban           N
# LP001091             NaN         Urban           N
# LP001123             NaN         Urban           Y
# LP001264             NaN     Semiurban           Y
# LP001273             NaN     Semiurban           N
# LP001280             NaN     Semiurban           Y
# LP001326             NaN         Urban           N
# LP001405             NaN         Urban           Y
# LP001443             NaN         Rural           Y
# LP001465             NaN         Rural           N
# LP001469             NaN         Urban           Y
# LP001541             NaN         Rural           Y
# LP001634             NaN         Rural           N
# LP001643             NaN         Rural           Y
# LP001671             NaN     Semiurban           Y
# LP001734             NaN     Semiurban           Y
# LP001786             NaN         Urban           N
# LP001788             NaN         Urban           Y
# LP001864             NaN     Semiurban           N
# LP001865             NaN         Urban           Y
# LP001908             NaN         Rural           Y
# LP001998             NaN         Rural           Y
# LP002008             NaN         Rural           Y
# LP002036             NaN         Urban           Y
# LP002043             NaN     Semiurban           Y
# LP002055             NaN         Rural           Y
# LP002137             NaN     Semiurban           Y
# LP002178             NaN         Urban           Y
# LP002223             NaN     Semiurban           Y
# LP002263             NaN         Urban           Y
# LP002272             NaN     Semiurban           Y
# LP002319             NaN         Urban           Y
# LP002424             NaN         Rural           Y
# LP002444             NaN     Semiurban           N
# LP002447             NaN         Urban           Y
# LP002478             NaN     Semiurban           Y
# LP002522             NaN         Urban           Y
# LP002560             NaN     Semiurban           Y
# LP002562             NaN         Urban           Y
# LP002588             NaN         Urban           Y
# LP002618             NaN         Rural           N
# LP002624             NaN         Urban           Y
# LP002717             NaN         Rural           Y
# LP002729             NaN     Semiurban           N
# LP002757             NaN     Semiurban           Y
# LP002794             NaN         Urban           Y
# LP002833             NaN         Rural           Y
# LP002898             NaN         Rural           N
# LP002949             NaN         Urban           N

# %%
# fill Credit_History na's with most common value
train['Credit_History'] = train['Credit_History'].fillna(1.0)
train.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0         NaN             360.0
# LP001003             4583             1508.0       128.0             360.0
# LP001005             3000                0.0        66.0             360.0
# LP001006             2583             2358.0       120.0             360.0
# LP001008             6000                0.0       141.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002             1.0         Urban           Y
# LP001003             1.0         Rural           N
# LP001005             1.0         Urban           Y
# LP001006             1.0         Urban           Y
# LP001008             1.0         Urban           Y

# %%
# check
train['Credit_History'].isnull().sum()
# Out:
# 0

# %%
# convert Credit_History to str type
train['Credit_History'] = train['Credit_History'].astype(int).astype(str)
train['Credit_History'].value_counts()
# Out:
# 1    525
# 0     89
# Name: Credit_History, dtype: int64

# %%
train.describe(include='all')
# Out:
#        Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# count     601     611        599       614           582       614.000000
# unique      2       2          4         2             2              NaN
# top      Male     Yes          0  Graduate            No              NaN
# freq      489     398        345       480           500              NaN
# mean      NaN     NaN        NaN       NaN           NaN      5403.459283
# std       NaN     NaN        NaN       NaN           NaN      6109.041673
# min       NaN     NaN        NaN       NaN           NaN       150.000000
# 25%       NaN     NaN        NaN       NaN           NaN      2877.500000
# 50%       NaN     NaN        NaN       NaN           NaN      3812.500000
# 75%       NaN     NaN        NaN       NaN           NaN      5795.000000
# max       NaN     NaN        NaN       NaN           NaN     81000.000000
#
#         CoapplicantIncome  LoanAmount  Loan_Amount_Term Credit_History  \
# count          614.000000  592.000000         600.00000            614
# unique                NaN         NaN               NaN              2
# top                   NaN         NaN               NaN              1
# freq                  NaN         NaN               NaN            525
# mean          1621.245798  146.412162         342.00000            NaN
# std           2926.248369   85.587325          65.12041            NaN
# min              0.000000    9.000000          12.00000            NaN
# 25%              0.000000  100.000000         360.00000            NaN
# 50%           1188.500000  128.000000         360.00000            NaN
# 75%           2297.250000  168.000000         360.00000            NaN
# max          41667.000000  700.000000         480.00000            NaN
#
#        Property_Area Loan_Status
# count            614         614
# unique             3           2
# top        Semiurban           Y
# freq             233         422
# mean             NaN         NaN
# std              NaN         NaN
# min              NaN         NaN
# 25%              NaN         NaN
# 50%              NaN         NaN
# 75%              NaN         NaN
# max              NaN         NaN

# %%
train['Loan_Amount_Term'].value_counts().sort_values()
# Out:
# 12.0       1
# 36.0       2
# 60.0       2
# 120.0      3
# 84.0       4
# 240.0      4
# 300.0     13
# 480.0     15
# 180.0     44
# 360.0    512
# Name: Loan_Amount_Term, dtype: int64

# %%
train['Loan_Amount_Term'] = train['Loan_Amount_Term'].fillna(0).astype(int).astype(str)

# %%
train['ApplicantIncome'] = train['ApplicantIncome'].astype(float)

# %%
train.dtypes
# Out:
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome      float64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term      object
# Credit_History        object
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
train.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
train[['Gender', 'Married', 'Dependents', 'Self_Employed']] = train[['Gender', 'Married', 'Dependents', 'Self_Employed']].fillna('DNA')

# %%
train.hist(column='LoanAmount');

# %%
train['LoanAmount'] = train['LoanAmount'].fillna(train['LoanAmount'].median())

# %%
train.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
train.dtypes
# Out:
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome      float64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term      object
# Credit_History        object
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
train = pd.get_dummies(train)
train.head()
# Out:
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Gender_DNA  \
# Loan_ID
# LP001002           5849.0                0.0       128.0           0
# LP001003           4583.0             1508.0       128.0           0
# LP001005           3000.0                0.0        66.0           0
# LP001006           2583.0             2358.0       120.0           0
# LP001008           6000.0                0.0       141.0           0
#
#           Gender_Female  Gender_Male  Married_DNA  Married_No  Married_Yes  \
# Loan_ID
# LP001002              0            1            0           1            0
# LP001003              0            1            0           0            1
# LP001005              0            1            0           0            1
# LP001006              0            1            0           0            1
# LP001008              0            1            0           1            0
#
#           Dependents_0  ...  Loan_Amount_Term_480  Loan_Amount_Term_60  \
# Loan_ID                 ...
# LP001002             1  ...                     0                    0
# LP001003             0  ...                     0                    0
# LP001005             1  ...                     0                    0
# LP001006             1  ...                     0                    0
# LP001008             1  ...                     0                    0
#
#           Loan_Amount_Term_84  Credit_History_0  Credit_History_1  \
# Loan_ID
# LP001002                    0                 0                 1
# LP001003                    0                 0                 1
# LP001005                    0                 0                 1
# LP001006                    0                 0                 1
# LP001008                    0                 0                 1
#
#           Property_Area_Rural  Property_Area_Semiurban  Property_Area_Urban  \
# Loan_ID
# LP001002                    0                        0                    1
# LP001003                    1                        0                    0
# LP001005                    0                        0                    1
# LP001006                    0                        0                    1
# LP001008                    0                        0                    1
#
#           Loan_Status_N  Loan_Status_Y
# Loan_ID
# LP001002              0              1
# LP001003              1              0
# LP001005              0              1
# LP001006              0              1
# LP001008              0              1
#
# [5 rows x 37 columns]

# %%
train.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Gender_DNA  \
# count       614.000000         614.000000  614.000000  614.000000
# mean       5403.459283        1621.245798  145.752443    0.021173
# std        6109.041673        2926.248369   84.107233    0.144077
# min         150.000000           0.000000    9.000000    0.000000
# 25%        2877.500000           0.000000  100.250000    0.000000
# 50%        3812.500000        1188.500000  128.000000    0.000000
# 75%        5795.000000        2297.250000  164.750000    0.000000
# max       81000.000000       41667.000000  700.000000    1.000000
#
#        Gender_Female  Gender_Male  Married_DNA  Married_No  Married_Yes  \
# count     614.000000   614.000000   614.000000  614.000000   614.000000
# mean        0.182410     0.796417     0.004886    0.346906     0.648208
# std         0.386497     0.402991     0.069786    0.476373     0.477919
# min         0.000000     0.000000     0.000000    0.000000     0.000000
# 25%         0.000000     1.000000     0.000000    0.000000     0.000000
# 50%         0.000000     1.000000     0.000000    0.000000     1.000000
# 75%         0.000000     1.000000     0.000000    1.000000     1.000000
# max         1.000000     1.000000     1.000000    1.000000     1.000000
#
#        Dependents_0  ...  Loan_Amount_Term_480  Loan_Amount_Term_60  \
# count    614.000000  ...            614.000000           614.000000
# mean       0.561889  ...              0.024430             0.003257
# std        0.496559  ...              0.154506             0.057026
# min        0.000000  ...              0.000000             0.000000
# 25%        0.000000  ...              0.000000             0.000000
# 50%        1.000000  ...              0.000000             0.000000
# 75%        1.000000  ...              0.000000             0.000000
# max        1.000000  ...              1.000000             1.000000
#
#        Loan_Amount_Term_84  Credit_History_0  Credit_History_1  \
# count           614.000000        614.000000        614.000000
# mean              0.006515          0.144951          0.855049
# std               0.080516          0.352339          0.352339
# min               0.000000          0.000000          0.000000
# 25%               0.000000          0.000000          1.000000
# 50%               0.000000          0.000000          1.000000
# 75%               0.000000          0.000000          1.000000
# max               1.000000          1.000000          1.000000
#
#        Property_Area_Rural  Property_Area_Semiurban  Property_Area_Urban  \
# count           614.000000               614.000000           614.000000
# mean              0.291531                 0.379479             0.328990
# std               0.454838                 0.485653             0.470229
# min               0.000000                 0.000000             0.000000
# 25%               0.000000                 0.000000             0.000000
# 50%               0.000000                 0.000000             0.000000
# 75%               1.000000                 1.000000             1.000000
# max               1.000000                 1.000000             1.000000
#
#        Loan_Status_N  Loan_Status_Y
# count     614.000000     614.000000
# mean        0.312704       0.687296
# std         0.463973       0.463973
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       1.000000
# 75%         1.000000       1.000000
# max         1.000000       1.000000
#
# [8 rows x 37 columns]

# %%
train.columns
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Gender_DNA',
#        'Gender_Female', 'Gender_Male', 'Married_DNA', 'Married_No',
#        'Married_Yes', 'Dependents_0', 'Dependents_1', 'Dependents_2',
#        'Dependents_3+', 'Dependents_DNA', 'Education_Graduate',
#        'Education_Not Graduate', 'Self_Employed_DNA', 'Self_Employed_No',
#        'Self_Employed_Yes', 'Loan_Amount_Term_0', 'Loan_Amount_Term_12',
#        'Loan_Amount_Term_120', 'Loan_Amount_Term_180', 'Loan_Amount_Term_240',
#        'Loan_Amount_Term_300', 'Loan_Amount_Term_36', 'Loan_Amount_Term_360',
#        'Loan_Amount_Term_480', 'Loan_Amount_Term_60', 'Loan_Amount_Term_84',
#        'Credit_History_0', 'Credit_History_1', 'Property_Area_Rural',
#        'Property_Area_Semiurban', 'Property_Area_Urban', 'Loan_Status_N',
#        'Loan_Status_Y'],
#       dtype='object')

# %%
features = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Gender_Male', 
            'Married_Yes', 'Dependents_0', 'Dependents_1', 'Dependents_2', 'Dependents_3+', 
            'Education_Graduate', 'Self_Employed_Yes', 'Loan_Amount_Term_12', 
            'Loan_Amount_Term_120', 'Loan_Amount_Term_180', 'Loan_Amount_Term_240', 
            'Loan_Amount_Term_300', 'Loan_Amount_Term_36', 'Loan_Amount_Term_360', 'Loan_Amount_Term_0', 
            'Loan_Amount_Term_480', 'Loan_Amount_Term_60', 'Loan_Amount_Term_84', 'Credit_History_1', 
            'Property_Area_Rural', 'Property_Area_Semiurban', 'Property_Area_Urban']

# %%
train[features].dtypes
# Out:
# ApplicantIncome            float64
# CoapplicantIncome          float64
# LoanAmount                 float64
# Gender_Male                  uint8
# Married_Yes                  uint8
# Dependents_0                 uint8
# Dependents_1                 uint8
# Dependents_2                 uint8
# Dependents_3+                uint8
# Education_Graduate           uint8
# Self_Employed_Yes            uint8
# Loan_Amount_Term_12          uint8
# Loan_Amount_Term_120         uint8
# Loan_Amount_Term_180         uint8
# Loan_Amount_Term_240         uint8
# Loan_Amount_Term_300         uint8
# Loan_Amount_Term_36          uint8
# Loan_Amount_Term_360         uint8
# Loan_Amount_Term_0           uint8
# Loan_Amount_Term_480         uint8
# Loan_Amount_Term_60          uint8
# Loan_Amount_Term_84          uint8
# Credit_History_1             uint8
# Property_Area_Rural          uint8
# Property_Area_Semiurban      uint8
# Property_Area_Urban          uint8
# dtype: object

# %%
# import k-means from clustering stage
from sklearn.cluster import KMeans

# %%
# set number of clusters
kclusters = 5

loan_clustering = train[features]

# run k-means clustering
kmeans = KMeans(init='k-means++', n_clusters=kclusters, random_state=0, n_init=12).fit(loan_clustering)

# check cluster labels generated for each row in the dataframe
train['clusters'] = kmeans.labels_

# %%
# add clustering labels
features.append('clusters')
features
# Out:
# ['ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Gender_Male',
#  'Married_Yes',
#  'Dependents_0',
#  'Dependents_1',
#  'Dependents_2',
#  'Dependents_3+',
#  'Education_Graduate',
#  'Self_Employed_Yes',
#  'Loan_Amount_Term_12',
#  'Loan_Amount_Term_120',
#  'Loan_Amount_Term_180',
#  'Loan_Amount_Term_240',
#  'Loan_Amount_Term_300',
#  'Loan_Amount_Term_36',
#  'Loan_Amount_Term_360',
#  'Loan_Amount_Term_0',
#  'Loan_Amount_Term_480',
#  'Loan_Amount_Term_60',
#  'Loan_Amount_Term_84',
#  'Credit_History_1',
#  'Property_Area_Rural',
#  'Property_Area_Semiurban',
#  'Property_Area_Urban',
#  'clusters']

# %%
from sklearn.preprocessing import StandardScaler

# %%
# set X and y
X = train[features]
y = train['Loan_Status_Y']

# %%
ss = StandardScaler()
X_ss = ss.fit_transform(X)
# Out:
# C:\Users\Mario Jr HP Laptop\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, int32, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Mario Jr HP Laptop\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype uint8, int32, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
train['Loan_Status_Y'].value_counts()
# Out:
# 1    422
# 0    192
# Name: Loan_Status_Y, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_ss, y, test_size= 0.25, stratify=y, random_state=42)

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# C:\Users\Mario Jr HP Laptop\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
cross_val_score(lr, X_train, y_train, cv=5).mean()
# Out:
# C:\Users\Mario Jr HP Laptop\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Mario Jr HP Laptop\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Mario Jr HP Laptop\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Mario Jr HP Laptop\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Mario Jr HP Laptop\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.7826680332290431

# %%
lr_preds = lr.predict(X_test)

# %%
lr_prob = lr.predict_proba(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print('Train score:', accuracy_score(y_train, lr.predict(X_train)))
print('Test score:', accuracy_score(y_test, lr_preds))
# Out:
# Train score: 0.8065217391304348
# Test score: 0.8636363636363636

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
confusion_matrix(y_test, lr_preds)
# Out:
# array([[ 29,  19],
#        [  2, 104]], dtype=int64)

# %%
print(classification_report(y_test, lr_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.60      0.73        48
#            1       0.85      0.98      0.91       106
#
#    micro avg       0.86      0.86      0.86       154
#    macro avg       0.89      0.79      0.82       154
# weighted avg       0.87      0.86      0.85       154

# %%
import matplotlib.pyplot as plt

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
print(confusion_matrix(y_test, lr_preds, labels=[0,1]))
# Out:
# [[ 29  19]
#  [  2 104]]

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, lr_preds, labels=[0,1])
np.set_printoptions(precision=2)


# Plot non-normalized confusion matrix
plt.figure(figsize=(10,10))
plot_confusion_matrix(cnf_matrix, classes=['Loan=0', 'Loan=1'], normalize= False, title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[ 29  19]
#  [  2 104]]

# %%
import sklearn.metrics as metrics
# calculate the fpr and tpr for all thresholds of the classification
probs = lr.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

# plot ROC/AUC Curve
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
test.isnull().sum()
# Out:
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
test[test['Loan_Amount_Term'].isnull()]
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001232   Male     Yes          0      Graduate            No
# LP001268   Male      No          0      Graduate            No
# LP001611   Male     Yes          1      Graduate            No
# LP001695   Male     Yes          1  Not Graduate            No
# LP002045   Male     Yes         3+      Graduate            No
# LP002183   Male     Yes          0  Not Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001232             4260               3900       185.0               NaN
# LP001268             6792               3338       187.0               NaN
# LP001611             1516               2900        80.0               NaN
# LP001695             3321               2088        70.0               NaN
# LP002045            10166                750       150.0               NaN
# LP002183             3754               3719       118.0               NaN
#
#           Credit_History Property_Area
# Loan_ID
# LP001232             NaN         Urban
# LP001268             1.0         Urban
# LP001611             0.0         Rural
# LP001695             1.0     Semiurban
# LP002045             1.0         Urban
# LP002183             1.0         Rural
